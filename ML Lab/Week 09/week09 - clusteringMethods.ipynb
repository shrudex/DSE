# %% [markdown]
# ## Q3 Clustering models on at least 4 datasets (using K-means, K-median, K-means++ & Hierarchical)

# %%
# !pip install scikit-learn-extra
# Out:
# Collecting scikit-learn-extra
#   Downloading scikit_learn_extra-0.3.0-cp39-cp39-win_amd64.whl (346 kB)
# Requirement already satisfied: scikit-learn>=0.23.0 in c:\users\codes\anaconda3\lib\site-packages (from scikit-learn-extra) (1.0.2)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\codes\anaconda3\lib\site-packages (from scikit-learn-extra) (1.21.5)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\codes\anaconda3\lib\site-packages (from scikit-learn-extra) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in c:\users\codes\anaconda3\lib\site-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\codes\anaconda3\lib\site-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (2.2.0)
# Installing collected packages: scikit-learn-extra
# Successfully installed scikit-learn-extra-0.3.0

# %%
from sklearn.datasets import load_breast_cancer, load_wine, load_digits, load_iris
from sklearn_extra.cluster import KMedoids
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# Load the datasets
datasets = [load_breast_cancer(), load_wine(), load_digits(), load_iris()]

# Define clustering algorithms
algorithms = [KMedoids(n_clusters=3, init='k-medoids++'), KMeans(n_clusters=3, init='k-means++'), AgglomerativeClustering(n_clusters=3)]

# Define test sizes
test_sizes = [0.1, 0.2, 0.3, 0.4]

# Loop over the datasets and algorithms
for dataset, dataset_name in zip(datasets, ['Breast Cancer', 'Wine', 'Digits', 'Iris']):
    X = dataset.data
    y = dataset.target
    print(f"Dataset: {dataset_name}")
    
    # Loop over the test sizes
    for test_size in test_sizes:
        # Split the data into training and testing sets
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
        print(f"Test size: {test_size}")
        
        for algorithm, algorithm_name in zip(algorithms, ['K-Medoids', 'K-Means++', 'Hierarchical']):
            y_pred = algorithm.fit_predict(X_train)
            sil_score = silhouette_score(X_train, y_pred)
            print(f"{algorithm_name} - Train Silhouette score: {sil_score:.3f}")
            plt.scatter(X_train[:, 0], X_train[:, 1], c=y_pred)
            plt.title(f"{algorithm_name} Training Clustering Results")
            plt.show()
            
            y_pred = algorithm.fit_predict(X_test)
            sil_score = silhouette_score(X_test, y_pred)
            print(f"{algorithm_name} - Test Silhouette score: {sil_score:.3f}")
            plt.scatter(X_test[:, 0], X_test[:, 1], c=y_pred)
            plt.title(f"{algorithm_name} Testing Clustering Results")
            plt.show()
    
    print()
# Out:
# Dataset: Breast Cancer
# Test size: 0.1
# K-Medoids - Train Silhouette score: 0.673
# K-Medoids - Test Silhouette score: 0.653
# K-Means++ - Train Silhouette score: 0.678
# K-Means++ - Test Silhouette score: 0.653
# Hierarchical - Train Silhouette score: 0.643
# Hierarchical - Test Silhouette score: 0.653
# Test size: 0.2
# K-Medoids - Train Silhouette score: 0.519
# K-Medoids - Test Silhouette score: 0.516
# K-Means++ - Train Silhouette score: 0.667
# K-Means++ - Test Silhouette score: 0.513
# Hierarchical - Train Silhouette score: 0.542
# Hierarchical - Test Silhouette score: 0.514
# Test size: 0.3
# K-Medoids - Train Silhouette score: 0.514
# K-Medoids - Test Silhouette score: 0.589
# K-Means++ - Train Silhouette score: 0.540
# K-Means++ - Test Silhouette score: 0.682
# Hierarchical - Train Silhouette score: 0.674
# Hierarchical - Test Silhouette score: 0.638
# Test size: 0.4
# K-Medoids - Train Silhouette score: 0.538
# K-Medoids - Test Silhouette score: 0.655
# K-Means++ - Train Silhouette score: 0.664
# K-Means++ - Test Silhouette score: 0.665
# Hierarchical - Train Silhouette score: 0.687
# Hierarchical - Test Silhouette score: 0.678
# Dataset: Wine
# Test size: 0.1
# K-Medoids - Train Silhouette score: 0.572
# K-Medoids - Test Silhouette score: 0.650
# K-Means++ - Train Silhouette score: 0.574
# K-Means++ - Test Silhouette score: 0.650
# Hierarchical - Train Silhouette score: 0.569
# Hierarchical - Test Silhouette score: 0.650
# Test size: 0.2
# K-Medoids - Train Silhouette score: 0.581
# K-Medoids - Test Silhouette score: 0.535
# K-Means++ - Train Silhouette score: 0.581
# K-Means++ - Test Silhouette score: 0.658
# Hierarchical - Train Silhouette score: 0.563
# Hierarchical - Test Silhouette score: 0.658
# Test size: 0.3
# K-Medoids - Train Silhouette score: 0.579
# K-Medoids - Test Silhouette score: 0.566
# K-Means++ - Train Silhouette score: 0.580
# K-Means++ - Test Silhouette score: 0.548
# Hierarchical - Train Silhouette score: 0.580
# Hierarchical - Test Silhouette score: 0.571
# Test size: 0.4
# K-Medoids - Train Silhouette score: 0.583
# K-Medoids - Test Silhouette score: 0.551
# K-Means++ - Train Silhouette score: 0.585
# K-Means++ - Test Silhouette score: 0.540
# Hierarchical - Train Silhouette score: 0.572
# Hierarchical - Test Silhouette score: 0.548
# Dataset: Digits
# Test size: 0.1
# K-Medoids - Train Silhouette score: 0.088
# K-Medoids - Test Silhouette score: 0.132
# K-Means++ - Train Silhouette score: 0.125
# K-Means++ - Test Silhouette score: 0.147
# Hierarchical - Train Silhouette score: 0.109
# Hierarchical - Test Silhouette score: 0.132
# Test size: 0.2
# K-Medoids - Train Silhouette score: 0.097
# K-Medoids - Test Silhouette score: 0.101
# K-Means++ - Train Silhouette score: 0.126
# K-Means++ - Test Silhouette score: 0.129
# Hierarchical - Train Silhouette score: 0.089
# Hierarchical - Test Silhouette score: 0.113
# Test size: 0.3
# K-Medoids - Train Silhouette score: 0.100
# K-Medoids - Test Silhouette score: 0.072
# K-Means++ - Train Silhouette score: 0.128
# K-Means++ - Test Silhouette score: 0.128
# Hierarchical - Train Silhouette score: 0.115
# Hierarchical - Test Silhouette score: 0.095
# Test size: 0.4
# K-Medoids - Train Silhouette score: 0.099
# K-Medoids - Test Silhouette score: 0.083
# K-Means++ - Train Silhouette score: 0.132
# K-Means++ - Test Silhouette score: 0.122
# Hierarchical - Train Silhouette score: 0.117
# Hierarchical - Test Silhouette score: 0.109
# Dataset: Iris
# Test size: 0.1
# K-Medoids - Train Silhouette score: 0.523
# K-Medoids - Test Silhouette score: 0.585
# K-Means++ - Train Silhouette score: 0.550
# K-Means++ - Test Silhouette score: 0.585
# Hierarchical - Train Silhouette score: 0.553
# Hierarchical - Test Silhouette score: 0.585
# Test size: 0.2
# K-Medoids - Train Silhouette score: 0.521
# K-Medoids - Test Silhouette score: 0.622
# K-Means++ - Train Silhouette score: 0.555
# K-Means++ - Test Silhouette score: 0.585
# Hierarchical - Train Silhouette score: 0.559
# Hierarchical - Test Silhouette score: 0.528
# Test size: 0.3
# K-Medoids - Train Silhouette score: 0.574
# K-Medoids - Test Silhouette score: 0.540
# K-Means++ - Train Silhouette score: 0.574
# K-Means++ - Test Silhouette score: 0.556
# Hierarchical - Train Silhouette score: 0.511
# Hierarchical - Test Silhouette score: 0.552
# Test size: 0.4
# K-Medoids - Train Silhouette score: 0.518
# K-Medoids - Test Silhouette score: 0.519
# K-Means++ - Train Silhouette score: 0.560
# K-Means++ - Test Silhouette score: 0.552
# Hierarchical - Train Silhouette score: 0.560
# Hierarchical - Test Silhouette score: 0.509
